# %%
# !pip install catboost -q
# !pip install optuna -q

# %%
import os
import sys
import pandas as pd
import numpy as np

# 모델
import sklearn 
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import f1_score
import catboost
from catboost import CatBoostClassifier
import optuna
from optuna.samplers import TPESampler
import joblib

np.random.seed(777)

# %%
train = pd.read_csv('./data/train_data.csv')
test = pd.read_csv('./data/test_data.csv')
sample_submission = pd.read_csv("./data/sample_submission.csv")

# %%
# 데이터 셋 나누기
X = train.drop('target', axis=1)
y = train['target']
X_test = test.copy()

# %%
# Optuna를 통한 하이퍼 파라미터 설정
def objective(trial):
    param = {"random_state": 777,
             "learning_rate": trial.suggest_loguniform('learning_rate', 0.01, 0.2),
             "bagging_temperature": trial.suggest_loguniform('bagging_temperature', 0.01, 100.00),
             "n_estimators": trial.suggest_int("n_estimators", 1000, 10000),
             "max_depth": trial.suggest_int("max_depth", 4, 16),
             "random_strength": trial.suggest_int('random_strength', 0, 100),
             "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.4, 1.0),
             "l2_leaf_reg": trial.suggest_float("l2_leaf_reg",1e-8,3e-5),
             "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
             "max_bin": trial.suggest_int("max_bin", 200, 500),
             "od_type": trial.suggest_categorical('od_type', ['IncToDec', 'Iter'])}

    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=777)
    cat = CatBoostClassifier(**param)
    cat.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid,y_valid)],
            early_stopping_rounds=35, verbose=False,
            cat_features=X_train.drop(['contents_rn_cnt', 'person_rn_cnt'], axis=1).columns.tolist())
    cat_pred = cat.predict(X_valid)
    f1 = f1_score(y_valid, cat_pred)

    return f1

study = optuna.create_study(study_name = 'cat_parameter_opt', direction = 'maximize', sampler = TPESampler(seed=777))
study.optimize(objective, n_trials=10)
print("Best Score:", study.best_value)
print("Best trial", study.best_trial.params)
# Out:
# [I 2022-01-30 07:26:17,477] A new study created in memory with name: cat_parameter_opt
# [I 2022-01-30 07:42:20,317] Trial 0 finished with value: 0.6856973452681508 and parameters: {'learning_rate': 0.01579865438088323, 'bagging_temperature': 0.16196696296443755, 'n_estimators': 1558, 'max_depth': 9, 'random_strength': 84, 'colsample_bylevel': 0.9561982286499368, 'l2_leaf_reg': 2.1812399639728913e-05, 'min_child_samples': 78, 'max_bin': 281, 'od_type': 'IncToDec'}. Best is trial 0 with value: 0.6856973452681508.
# [I 2022-01-30 08:20:08,661] Trial 1 finished with value: 0.6666345105681019 and parameters: {'learning_rate': 0.012696199189652336, 'bagging_temperature': 2.2827324567331666, 'n_estimators': 4090, 'max_depth': 16, 'random_strength': 63, 'colsample_bylevel': 0.8090675678685719, 'l2_leaf_reg': 1.6572181843977423e-05, 'min_child_samples': 30, 'max_bin': 312, 'od_type': 'IncToDec'}. Best is trial 0 with value: 0.6856973452681508.
# [I 2022-01-30 08:30:15,030] Trial 2 finished with value: 0.6578536443431454 and parameters: {'learning_rate': 0.03222885580142552, 'bagging_temperature': 0.059244716081472554, 'n_estimators': 6498, 'max_depth': 15, 'random_strength': 62, 'colsample_bylevel': 0.5518713665227417, 'l2_leaf_reg': 5.4061098987766825e-06, 'min_child_samples': 83, 'max_bin': 267, 'od_type': 'Iter'}. Best is trial 0 with value: 0.6856973452681508.
# [I 2022-01-30 08:39:10,537] Trial 3 finished with value: 0.6880794511897587 and parameters: {'learning_rate': 0.06040957772600507, 'bagging_temperature': 1.350460640529066, 'n_estimators': 1119, 'max_depth': 10, 'random_strength': 90, 'colsample_bylevel': 0.8619407766309486, 'l2_leaf_reg': 3.6943223670876182e-06, 'min_child_samples': 33, 'max_bin': 384, 'od_type': 'IncToDec'}. Best is trial 3 with value: 0.6880794511897587.
# [I 2022-01-30 08:43:22,679] Trial 4 finished with value: 0.682502630823687 and parameters: {'learning_rate': 0.10014647276869659, 'bagging_temperature': 0.05841496543972007, 'n_estimators': 6021, 'max_depth': 11, 'random_strength': 47, 'colsample_bylevel': 0.8751309763770452, 'l2_leaf_reg': 3.466337850301751e-06, 'min_child_samples': 70, 'max_bin': 309, 'od_type': 'Iter'}. Best is trial 3 with value: 0.6880794511897587.
# [I 2022-01-30 09:45:37,309] Trial 5 finished with value: 0.691520678115621 and parameters: {'learning_rate': 0.010840584251066899, 'bagging_temperature': 0.4581321386413516, 'n_estimators': 9301, 'max_depth': 5, 'random_strength': 31, 'colsample_bylevel': 0.7168133464782174, 'l2_leaf_reg': 9.848580301053825e-06, 'min_child_samples': 48, 'max_bin': 204, 'od_type': 'Iter'}. Best is trial 5 with value: 0.691520678115621.
# [I 2022-01-30 09:49:14,667] Trial 6 finished with value: 0.6829286994527138 and parameters: {'learning_rate': 0.12234534515198324, 'bagging_temperature': 0.49806721947575194, 'n_estimators': 8639, 'max_depth': 11, 'random_strength': 35, 'colsample_bylevel': 0.8363498092887638, 'l2_leaf_reg': 2.824611833312177e-06, 'min_child_samples': 90, 'max_bin': 301, 'od_type': 'IncToDec'}. Best is trial 5 with value: 0.691520678115621.
# [I 2022-01-30 10:01:21,424] Trial 7 finished with value: 0.68286197959008 and parameters: {'learning_rate': 0.02468615624559694, 'bagging_temperature': 16.786588085270797, 'n_estimators': 8539, 'max_depth': 12, 'random_strength': 31, 'colsample_bylevel': 0.41766914757482315, 'l2_leaf_reg': 1.1999321713652917e-05, 'min_child_samples': 54, 'max_bin': 202, 'od_type': 'Iter'}. Best is trial 5 with value: 0.691520678115621.
# [I 2022-01-30 10:26:21,853] Trial 8 finished with value: 0.6694722650231125 and parameters: {'learning_rate': 0.014829555719168601, 'bagging_temperature': 0.14147984525233936, 'n_estimators': 3939, 'max_depth': 15, 'random_strength': 100, 'colsample_bylevel': 0.8625305754752923, 'l2_leaf_reg': 1.2949970471837188e-06, 'min_child_samples': 97, 'max_bin': 493, 'od_type': 'Iter'}. Best is trial 5 with value: 0.691520678115621.
# [I 2022-01-30 10:47:13,546] Trial 9 finished with value: 0.6938205204275966 and parameters: {'learning_rate': 0.04031140044870307, 'bagging_temperature': 47.87071560332222, 'n_estimators': 7554, 'max_depth': 7, 'random_strength': 1, 'colsample_bylevel': 0.8235932881616793, 'l2_leaf_reg': 2.323674135181441e-05, 'min_child_samples': 50, 'max_bin': 441, 'od_type': 'Iter'}. Best is trial 9 with value: 0.6938205204275966.
# Best Score: 0.6938205204275966
# Best trial {'learning_rate': 0.04031140044870307, 'bagging_temperature': 47.87071560332222, 'n_estimators': 7554, 'max_depth': 7, 'random_strength': 1, 'colsample_bylevel': 0.8235932881616793, 'l2_leaf_reg': 2.323674135181441e-05, 'min_child_samples': 50, 'max_bin': 441, 'od_type': 'Iter'}

# %%
## 하이퍼 파리미터 저장
joblib.dump(study, "./model/model/opt_catboost.pkl")
